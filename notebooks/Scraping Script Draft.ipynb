# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin

BASE_URL = "https://www.tennisabstract.com/"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; student-project/1.0)"
}

response = requests.get(BASE_URL, headers=headers, timeout=15)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

links = []

for a in soup.find_all("a", href=True):
    text = a.get_text(strip=True)
    href = urljoin(BASE_URL, a["href"])
    links.append({
        "text": text,
        "url": href
    })

links_df = pd.DataFrame(links)
links_df.head(30)
# Out:
#                                                  text  \
# 0                                  tennisabstract.com
# 1                                       Marta Kostyuk
# 2                               Felix Auger Aliassime
# 3                                    Yulia Putintseva
# 4                                         Ben Shelton
# 5                                      Elena Rybakina
# 6                                        Jakub Mensik
# 7                                charting pro matches
# 8                 thousands of detailed match reports
# 9   2026 Rome R128: Tyra Caterina Grant vs Lisa Pi...
# 10  2026 Madrid Masters R32: Jannik Sinner vs Elme...
# 11  2026 Madrid QF: Aryna Sabalenka vs Hailey Bapt...
# 12                         ...and over 17,000 more...
# 13                                      Heavy Topspin
# 14                         Do Pushers Grow Out Of It?
# 15  What Does Felix Auger-Aliassime Do So Right On...
# 16        Defanging the Ball Bashers With Sara Bejlek
# 17  Carlos Alcaraz Will Return Your Serve. Good Lu...
# 18  The Rybakina Serves That Tipped the Scale In t...
# 19                                        settesei.it
# 20          Elena Rybakina e l’importanza della media
# 21                I 128 del tennis — #29, Andy Murray
# 22                                        Doble Falta
# 23  Carlos Alcaraz te va a devolver el saque. Suer...
# 24  El declive de la especialización (o el listón ...
# 25                              Results and Forecasts
# 26                                    Elina Svitolina
# 27                              Results and Forecasts
# 28                                  Dayana Yastremska
# 29                              Results and Forecasts
#
#                                                   url
# 0                      https://www.tennisabstract.com
# 1   https://www.tennisabstract.com/cgi-bin/wplayer...
# 2   https://www.tennisabstract.com/cgi-bin/player....
# 3   https://www.tennisabstract.com/cgi-bin/wplayer...
# 4   https://www.tennisabstract.com/cgi-bin/player....
# 5   https://www.tennisabstract.com/cgi-bin/wplayer...
# 6   https://www.tennisabstract.com/cgi-bin/player....
# 7   https://www.tennisabstract.com/blog/2015/09/23...
# 8   https://www.tennisabstract.com/charting/meta.html
# 9   https://www.tennisabstract.com/charting/202605...
# 10  https://www.tennisabstract.com/charting/202604...
# 11  https://www.tennisabstract.com/charting/202604...
# 12  https://www.tennisabstract.com/charting/meta.html
# 13                   https://tennisabstract.com/blog/
# 14  https://www.tennisabstract.com/blog/2026/04/16...
# 15  https://www.tennisabstract.com/blog/2026/02/11...
# 16  https://www.tennisabstract.com/blog/2026/02/09...
# 17  https://www.tennisabstract.com/blog/2026/02/03...
# 18  https://www.tennisabstract.com/blog/2026/02/02...
# 19                           https://www.settesei.it/
# 20  https://www.settesei.it/2026/05/11/elena-rybak...
# 21  https://www.settesei.it/2026/04/14/i-128-del-t...
# 22             https://tennisabstract.com/doblefalta/
# 23  https://www.tennisabstract.com/doblefalta/carl...
# 24  https://www.tennisabstract.com/doblefalta/el-d...
# 25  https://www.tennisabstract.com/current/2026WTA...
# 26  https://www.tennisabstract.com/cgi-bin/wplayer...
# 27  https://www.tennisabstract.com/current/2026WTA...
# 28  https://www.tennisabstract.com/cgi-bin/wplayer...
# 29  https://www.tennisabstract.com/current/2026WTA...

# %%
len(links_df)
# Out:
# 269

# %%
links_df
# Out:
#                         text  \
# 0         tennisabstract.com
# 1              Marta Kostyuk
# 2      Felix Auger Aliassime
# 3           Yulia Putintseva
# 4                Ben Shelton
# ..                       ...
# 264          Jaroslav Drobny
# 265            Jannik Sinner
# 266  Margaret Osborne duPont
# 267      Sarah Palfrey Cooke
# 268     Beverly Baker Fleitz
#
#                                                    url
# 0                       https://www.tennisabstract.com
# 1    https://www.tennisabstract.com/cgi-bin/wplayer...
# 2    https://www.tennisabstract.com/cgi-bin/player....
# 3    https://www.tennisabstract.com/cgi-bin/wplayer...
# 4    https://www.tennisabstract.com/cgi-bin/player....
# ..                                                 ...
# 264  https://www.tennisabstract.com/blog/2022/09/22...
# 265  https://www.tennisabstract.com/blog/2025/02/07...
# 266  https://www.tennisabstract.com/blog/2022/05/12...
# 267  https://www.tennisabstract.com/blog/2022/03/26...
# 268  https://www.tennisabstract.com/blog/2022/02/03...
#
# [269 rows x 2 columns]
